# %% [markdown]
# ### Data Loading
# #### Create an independent script to load the Zomato restaurant data available here into a database.

# %%
import subprocess
import sys
import os

# Function to install a package using pip
def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

# Try to import pandas and install if not found
try:
    import pandas as pd
except ImportError:
    print("Pandas not found. Installing...")
    install("pandas")
    import pandas as pd

# Specify the file path
file_path = 'archive/zomato.csv'

if not os.path.exists(file_path):
    print(f"File not found: {file_path}")
    sys.exit(1)


# Load the CSV file
zomato_data = pd.read_csv(file_path, encoding='ISO-8859-1')

zomato_data.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                    Japanese  ...  Botswana Pula(P)               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# 1                  No                No                   No           3
#
#    Aggregate rating  Rating color Rating text Votes
# 0               4.8    Dark Green   Excellent   314
# 1               4.5    Dark Green   Excellent   591
#
# [2 rows x 21 columns]

# %% [markdown]
# ### Web API Service
# #### Develop a web API service with the following endpoints to serve the content loaded in the previous step:
#
# Get Restaurant by ID: Retrieve details of a specific restaurant by its ID.
#
# Get List of Restaurants: Fetch a list of restaurants with pagination support.

# %%
zomato_data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# Get Restaurant by ID: Retrieve details of a specific restaurant by its ID. colName = Restaurant ID
# check rtestraunt id is unique or not
zomato_dict = zomato_data.set_index('Restaurant ID').T.to_dict()

# %%
zomato_dict
# Out:
# {6317637: {'Restaurant Name': 'Le Petit Souffle',
#   'Country Code': 162,
#   'City': 'Makati City',
#   'Address': 'Third Floor, Century City Mall, Kalayaan Avenue, Poblacion, Makati City',
#   'Locality': 'Century City Mall, Poblacion, Makati City',
#   'Locality Verbose': 'Century City Mall, Poblacion, Makati City, Makati City',
#   'Longitude': 121.027535,
#   'Latitude': 14.565443,
#   'Cuisines': 'French, Japanese, Desserts',
#   'Average Cost for two': 1100,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'Yes',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.8,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 314},
#  6304287: {'Restaurant Name': 'Izakaya Kikufuji',
#   'Country Code': 162,
#   'City': 'Makati City',
#   'Address': 'Little Tokyo, 2277 Chino Roces Avenue, Legaspi Village, Makati City',
#   'Locality': 'Little Tokyo, Legaspi Village, Makati City',
#   'Locality Verbose': 'Little Tokyo, Legaspi Village, Makati City, Makati City',
#   'Longitude': 121.014101,
#   'Latitude': 14.553708,
#   'Cuisines': 'Japanese',
#   'Average Cost for two': 1200,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'Yes',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.5,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 591},
#  6300002: {'Restaurant Name': 'Heat - Edsa Shangri-La',
#   'Country Code': 162,
#   'City': 'Mandaluyong City',
#   'Address': 'Edsa Shangri-La, 1 Garden Way, Ortigas, Mandaluyong City',
#   'Locality': 'Edsa Shangri-La, Ortigas, Mandaluyong City',
#   'Locality Verbose': 'Edsa Shangri-La, Ortigas, Mandaluyong City, Mandaluyong City',
#   'Longitude': 121.056831,
#   'Latitude': 14.581404,
#   'Cuisines': 'Seafood, Asian, Filipino, Indian',
#   'Average Cost for two': 4000,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'Yes',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.4,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 270},
#  6318506: {'Restaurant Name': 'Ooma',
#   'Country Code': 162,
#   'City': 'Mandaluyong City',
#   'Address': 'Third Floor, Mega Fashion Hall, SM Megamall, Ortigas, Mandaluyong City',
#   'Locality': 'SM Megamall, Ortigas, Mandaluyong City',
#   'Locality Verbose': 'SM Megamall, Ortigas, Mandaluyong City, Mandaluyong City',
#   'Longitude': 121.056475,
#   'Latitude': 14.585318,
#   'Cuisines': 'Japanese, Sushi',
#   'Average Cost for two': 1500,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.9,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 365},
#  6314302: {'Restaurant Name': 'Sambo Kojin',
#   'Country Code': 162,
#   'City': 'Mandaluyong City',
#   'Address': 'Third Floor, Mega Atrium, SM Megamall, Ortigas, Mandaluyong City',
#   'Locality': 'SM Megamall, Ortigas, Mandaluyong City',
#   'Locality Verbose': 'SM Megamall, Ortigas, Mandaluyong City, Mandaluyong City',
#   'Longitude': 121.057508,
#   'Latitude': 14.58445,
#   'Cuisines': 'Japanese, Korean',
#   'Average Cost for two': 1500,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'Yes',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.8,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 229},
#  18189371: {'Restaurant Name': 'Din Tai Fung',
#   'Country Code': 162,
#   'City': 'Mandaluyong City',
#   'Address': 'Ground Floor, Mega Fashion Hall, SM Megamall, Ortigas, Mandaluyong City',
#   'Locality': 'SM Megamall, Ortigas, Mandaluyong City',
#   'Locality Verbose': 'SM Megamall, Ortigas, Mandaluyong City, Mandaluyong City',
#   'Longitude': 121.056314,
#   'Latitude': 14.583764,
#   'Cuisines': 'Chinese',
#   'Average Cost for two': 1000,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.4,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 336},
#  6300781: {'Restaurant Name': 'Buffet 101',
#   'Country Code': 162,
#   'City': 'Pasay City',
#   'Address': 'Building K, SM By The Bay, Sunset Boulevard, Mall of Asia Complex (MOA), Pasay City',
#   'Locality': 'SM by the Bay, Mall of Asia Complex, Pasay City',
#   'Locality Verbose': 'SM by the Bay, Mall of Asia Complex, Pasay City, Pasay City',
#   'Longitude': 120.9796667,
#   'Latitude': 14.53133333,
#   'Cuisines': 'Asian, European',
#   'Average Cost for two': 2000,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'Yes',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.0,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 520},
#  6301290: {'Restaurant Name': 'Vikings',
#   'Country Code': 162,
#   'City': 'Pasay City',
#   'Address': 'Building B, By The Bay, Seaside Boulevard, Mall of Asia Complex (MOA), Pasay City',
#   'Locality': 'SM by the Bay, Mall of Asia Complex, Pasay City',
#   'Locality Verbose': 'SM by the Bay, Mall of Asia Complex, Pasay City, Pasay City',
#   'Longitude': 120.9793333,
#   'Latitude': 14.54,
#   'Cuisines': 'Seafood, Filipino, Asian, European',
#   'Average Cost for two': 2000,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'Yes',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.2,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 677},
#  6300010: {'Restaurant Name': 'Spiral - Sofitel Philippine Plaza Manila',
#   'Country Code': 162,
#   'City': 'Pasay City',
#   'Address': 'Plaza Level, Sofitel Philippine Plaza Manila, CCP Complex, Pasay City',
#   'Locality': 'Sofitel Philippine Plaza Manila, Pasay City',
#   'Locality Verbose': 'Sofitel Philippine Plaza Manila, Pasay City, Pasay City',
#   'Longitude': 120.98009,
#   'Latitude': 14.55299,
#   'Cuisines': 'European, Asian, Indian',
#   'Average Cost for two': 6000,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'Yes',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.9,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 621},
#  6314987: {'Restaurant Name': 'Locavore',
#   'Country Code': 162,
#   'City': 'Pasig City',
#   'Address': 'Brixton Technology Center, 10 Brixton Street, Kapitolyo, Pasig City',
#   'Locality': 'Kapitolyo',
#   'Locality Verbose': 'Kapitolyo, Pasig City',
#   'Longitude': 121.056532,
#   'Latitude': 14.572041,
#   'Cuisines': 'Filipino',
#   'Average Cost for two': 1100,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'Yes',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.8,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 532},
#  6309903: {'Restaurant Name': 'Silantro Fil-Mex',
#   'Country Code': 162,
#   'City': 'Pasig City',
#   'Address': '75 East Capitol Drive, Kapitolyo, Pasig City',
#   'Locality': 'Kapitolyo',
#   'Locality Verbose': 'Kapitolyo, Pasig City',
#   'Longitude': 121.057916,
#   'Latitude': 14.567689,
#   'Cuisines': 'Filipino, Mexican',
#   'Average Cost for two': 800,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.9,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 1070},
#  6309455: {'Restaurant Name': "Mad Mark's Creamery & Good Eats",
#   'Country Code': 162,
#   'City': 'Pasig City',
#   'Address': '23 East Capitol Drive, Kapitolyo, Pasig City',
#   'Locality': 'Kapitolyo',
#   'Locality Verbose': 'Kapitolyo, Pasig City',
#   'Longitude': 121.06082,
#   'Latitude': 14.570849,
#   'Cuisines': 'American, Ice Cream, Desserts',
#   'Average Cost for two': 900,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'Yes',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.2,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 488},
#  6318433: {'Restaurant Name': 'Silantro Fil-Mex',
#   'Country Code': 162,
#   'City': 'Quezon City',
#   'Address': 'Second Floor, UP Town Center, Katipunan Avenue, Diliman, Quezon City',
#   'Locality': 'UP Town Center, Diliman, Quezon City',
#   'Locality Verbose': 'UP Town Center, Diliman, Quezon City, Quezon City',
#   'Longitude': 121.075419,
#   'Latitude': 14.649503,
#   'Cuisines': 'Filipino, Mexican',
#   'Average Cost for two': 800,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.8,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 294},
#  6310470: {'Restaurant Name': "Guevarra's",
#   'Country Code': 162,
#   'City': 'San Juan City',
#   'Address': '387 P. Guevarra Corner Argonne Street, Addition Hills, San Juan City',
#   'Locality': 'Addition Hills',
#   'Locality Verbose': 'Addition Hills, San Juan City',
#   'Longitude': 121.0335917,
#   'Latitude': 14.59345,
#   'Cuisines': 'Filipino',
#   'Average Cost for two': 1000,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'Yes',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.2,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 458},
#  6314605: {'Restaurant Name': 'Sodam Korean Restaurant',
#   'Country Code': 162,
#   'City': 'San Juan City',
#   'Address': '17 J. Abad Santos Drive, Little Baguio, San Juan City',
#   'Locality': 'Little Baguio',
#   'Locality Verbose': 'Little Baguio, San Juan City',
#   'Longitude': 121.03811,
#   'Latitude': 14.59889,
#   'Cuisines': 'Korean',
#   'Average Cost for two': 700,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.3,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 223},
#  18185059: {'Restaurant Name': 'Cafe Arabelle',
#   'Country Code': 162,
#   'City': 'Santa Rosa',
#   'Address': 'Ayala Mall, Solenad, Nuvali, Santa Rosa - Tagaytay Road, Don Jose, Santa Rosa',
#   'Locality': 'Nuvali, Don Jose, Santa Rosa',
#   'Locality Verbose': 'Nuvali, Don Jose, Santa Rosa, Santa Rosa',
#   'Longitude': 121.05704,
#   'Latitude': 14.237082,
#   'Cuisines': 'Cafe, American, Italian, Filipino',
#   'Average Cost for two': 800,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 3.6,
#   'Rating color': 'Yellow',
#   'Rating text': 'Good',
#   'Votes': 29},
#  18182702: {'Restaurant Name': "Nonna's Pasta & Pizzeria",
#   'Country Code': 162,
#   'City': 'Santa Rosa',
#   'Address': 'Ground Floor, Building G, Solenad 3, Nuvali, Don Jose, Santa Rosa',
#   'Locality': 'Solenad 3, Don Jose, Santa Rosa',
#   'Locality Verbose': 'Solenad 3, Don Jose, Santa Rosa, Santa Rosa',
#   'Longitude': 121.0565874,
#   'Latitude': 14.23767897,
#   'Cuisines': 'Italian, Pizza',
#   'Average Cost for two': 850,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.0,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 72},
#  6318213: {'Restaurant Name': 'Balay Dako',
#   'Country Code': 162,
#   'City': 'Tagaytay City',
#   'Address': 'Aguinaldo Highway, Tagaytay City',
#   'Locality': 'Tagaytay City',
#   'Locality Verbose': 'Tagaytay City, Tagaytay City',
#   'Longitude': 120.951589,
#   'Latitude': 14.101834,
#   'Cuisines': 'Filipino',
#   'Average Cost for two': 1200,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'Yes',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.5,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 211},
#  18255654: {'Restaurant Name': 'Hobing Korean Dessert Cafe',
#   'Country Code': 162,
#   'City': 'Taguig City',
#   'Address': 'Third Floor, BGC Stopover Pavillion, Rizal Drive Corner 31st Street, Bonifacio Global City, Taguig City',
#   'Locality': 'BGC Stopover Pavillion, Bonifacio Global City',
#   'Locality Verbose': 'BGC Stopover Pavillion, Bonifacio Global City, Taguig City',
#   'Longitude': 121.045878,
#   'Latitude': 14.55436,
#   'Cuisines': 'Cafe, Korean, Desserts',
#   'Average Cost for two': 600,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 4.5,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 118},
#  6308205: {'Restaurant Name': 'Wildflour Cafe + Bakery',
#   'Country Code': 162,
#   'City': 'Taguig City',
#   'Address': 'Ground Floor, Netlima Building, 4th Avenue Corner 26th Street, Bonifacio Global City, Taguig City',
#   'Locality': 'Bonifacio Global City',
#   'Locality Verbose': 'Bonifacio Global City, Taguig City',
#   'Longitude': 121.04622,
#   'Latitude': 14.549337,
#   'Cuisines': 'Cafe, Bakery, American, Italian',
#   'Average Cost for two': 1500,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'Yes',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.4,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 392},
#  6315438: {'Restaurant Name': 'NIU by Vikings',
#   'Country Code': 162,
#   'City': 'Taguig City',
#   'Address': 'Sixth Floor, SM Aura Premier, C5 Road Corner 26th Street, Bonifacio Global City, Taguig City',
#   'Locality': 'SM Aura Premier, Bonifacio Global City, Taguig City',
#   'Locality Verbose': 'SM Aura Premier, Bonifacio Global City, Taguig City, Taguig City',
#   'Longitude': 121.053725,
#   'Latitude': 14.545858,
#   'Cuisines': 'Seafood, American, Mediterranean, Japanese',
#   'Average Cost for two': 3000,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'Yes',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.7,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 535},
#  6310406: {'Restaurant Name': 'The Food Hall by Todd English',
#   'Country Code': 162,
#   'City': 'Taguig City',
#   'Address': 'Fifth Floor, SM Aura Premier, C5 Corner 26th Street, Bonifacio Global City, Taguig City',
#   'Locality': 'SM Aura Premier, Bonifacio Global City, Taguig City',
#   'Locality Verbose': 'SM Aura Premier, Bonifacio Global City, Taguig City, Taguig City',
#   'Longitude': 121.0534998,
#   'Latitude': 14.54565535,
#   'Cuisines': 'American, Asian, Italian, Seafood',
#   'Average Cost for two': 1800,
#   'Currency': 'Botswana Pula(P)',
#   'Has Table booking': 'Yes',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.5,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 618},
#  6600681: {'Restaurant Name': 'Chez Michou',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'SCLN, 208, Bloco A, Loja 30, Asa Norte, Brasí_lia',
#   'Locality': 'Asa Norte',
#   'Locality Verbose': 'Asa Norte, Brasí_lia',
#   'Longitude': -47.88178889,
#   'Latitude': -15.76414167,
#   'Cuisines': 'Fast Food, French',
#   'Average Cost for two': 55,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 3.0,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 6},
#  6601005: {'Restaurant Name': 'Cafí© Daniel Briand',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'SCLN 104, Bloco A, Loja 26, Asa Norte, Brasí_lia',
#   'Locality': 'Asa Norte',
#   'Locality Verbose': 'Asa Norte, Brasí_lia',
#   'Longitude': -47.88266667,
#   'Latitude': -15.7775,
#   'Cuisines': 'Cafe',
#   'Average Cost for two': 30,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 3.8,
#   'Rating color': 'Yellow',
#   'Rating text': 'Good',
#   'Votes': 9},
#  6600292: {'Restaurant Name': 'Casa do Biscoito Mineiro',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'SCLN 210, Bloco D, Loja 36/48, Asa Norte, Brasí_lia',
#   'Locality': 'Asa Norte',
#   'Locality Verbose': 'Asa Norte, Brasí_lia',
#   'Longitude': -47.88213611,
#   'Latitude': -15.75747222,
#   'Cuisines': 'Bakery',
#   'Average Cost for two': 45,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 3.7,
#   'Rating color': 'Yellow',
#   'Rating text': 'Good',
#   'Votes': 11},
#  6600441: {'Restaurant Name': 'Maori',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'CLN 110, Bloco D, Loja 28, Asa Norte, Brasí_lia',
#   'Locality': 'Asa Norte',
#   'Locality Verbose': 'Asa Norte, Brasí_lia',
#   'Longitude': -47.88816667,
#   'Latitude': -15.75883333,
#   'Cuisines': 'Brazilian',
#   'Average Cost for two': 60,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 3.8,
#   'Rating color': 'Yellow',
#   'Rating text': 'Good',
#   'Votes': 11},
#  6600970: {'Restaurant Name': 'Pizza íæ Bessa',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'SCS 214, Bloco C, Loja 40, Asa Sul, Brasí_lia',
#   'Locality': 'Asa Sul',
#   'Locality Verbose': 'Asa Sul, Brasí_lia',
#   'Longitude': -47.91566667,
#   'Latitude': -15.83116667,
#   'Cuisines': 'Pizza',
#   'Average Cost for two': 50,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 3.2,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 11},
#  6600379: {'Restaurant Name': 'Sushi Loko',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'SCS 213, Bloco C, Loja 35, Asa Sul, Brasí_lia',
#   'Locality': 'Asa Sul',
#   'Locality Verbose': 'Asa Sul, Brasí_lia',
#   'Longitude': -47.91566667,
#   'Latitude': -15.831,
#   'Cuisines': 'Japanese',
#   'Average Cost for two': 80,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 3.1,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 10},
#  6600214: {'Restaurant Name': 'Beirute',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'CLS 109, Bloco A, Loja 2/6, Asa Sul, Brasí_lia',
#   'Locality': 'Asa Sul',
#   'Locality Verbose': 'Asa Sul, Brasí_lia',
#   'Longitude': -47.9075,
#   'Latitude': -15.82,
#   'Cuisines': 'Arabian',
#   'Average Cost for two': 90,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 3.7,
#   'Rating color': 'Yellow',
#   'Rating text': 'Good',
#   'Votes': 8},
#  6601218: {'Restaurant Name': 'New Koto',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'SCS 212, Bloco B, Loja 26, Asa Sul, Brasí_lia',
#   'Locality': 'Asa Sul',
#   'Locality Verbose': 'Asa Sul, Brasí_lia',
#   'Longitude': -47.91016667,
#   'Latitude': -15.82733333,
#   'Cuisines': 'Japanese',
#   'Average Cost for two': 200,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 3.7,
#   'Rating color': 'Yellow',
#   'Rating text': 'Good',
#   'Votes': 5},
#  6600060: {'Restaurant Name': 'Sandubas Cafí©',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'Edifí_cio Josí© Severo, SCS 6, Bloco A, Loja 99, Asa Sul, Brasí_lia',
#   'Locality': 'Asa Sul',
#   'Locality Verbose': 'Asa Sul, Brasí_lia',
#   'Longitude': -47.89016667,
#   'Latitude': -15.797,
#   'Cuisines': 'Brazilian, Cafe',
#   'Average Cost for two': 30,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 0.0,
#   'Rating color': 'White',
#   'Rating text': 'Not rated',
#   'Votes': 2},
#  6600083: {'Restaurant Name': 'Villa Tevere',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'CLS 115, Bloco A, Loja 2, Asa Sul, Brasí_lia',
#   'Locality': 'Asa Sul',
#   'Locality Verbose': 'Asa Sul, Brasí_lia',
#   'Longitude': -47.92366667,
#   'Latitude': -15.83133333,
#   'Cuisines': 'Italian',
#   'Average Cost for two': 150,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.1,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 12},
#  6601515: {'Restaurant Name': 'Rovereto',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'Rua 13 Norte, Lote 4, í\x81guas Claras, Brasí_lia',
#   'Locality': 'í\x81guas Claras',
#   'Locality Verbose': 'í\x81guas Claras, Brasí_lia',
#   'Longitude': -48.019,
#   'Latitude': -15.83716667,
#   'Cuisines': 'Pizza',
#   'Average Cost for two': 100,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 3.1,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 9},
#  6601361: {'Restaurant Name': 'Buena Carne',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'Avenida Araucíçrias, 1325, Loja 19, í\x81guas Claras, Brasí_lia',
#   'Locality': 'í\x81guas Claras',
#   'Locality Verbose': 'í\x81guas Claras, Brasí_lia',
#   'Longitude': -48.01909167,
#   'Latitude': -15.839775,
#   'Cuisines': 'Bar Food, Brazilian',
#   'Average Cost for two': 60,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 3.6,
#   'Rating color': 'Yellow',
#   'Rating text': 'Good',
#   'Votes': 9},
#  6601602: {'Restaurant Name': 'Taco Pep',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'Vila Malls, Avenida das Castanheiras, Lote 1060, í\x80guas Claras, Brasí_lia',
#   'Locality': 'í\x81guas Claras',
#   'Locality Verbose': 'í\x81guas Claras, Brasí_lia',
#   'Longitude': -48.01666667,
#   'Latitude': -15.83483333,
#   'Cuisines': 'Mexican, Grill',
#   'Average Cost for two': 100,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.3,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 29},
#  6601589: {'Restaurant Name': 'Coco Bambu',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'Brasí_lia Shopping - Piso 2, SCN 5, Bloco A, Asa Norte, Brasí_lia',
#   'Locality': 'Brasí_lia Shopping, Asa Norte',
#   'Locality Verbose': 'Brasí_lia Shopping, Asa Norte, Brasí_lia',
#   'Longitude': -47.889,
#   'Latitude': -15.7865,
#   'Cuisines': 'International',
#   'Average Cost for two': 230,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.2,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 17},
#  6601862: {'Restaurant Name': 'Taypíç',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'Fashion Park, Shis Ql 17, Bloco G, Loja 208, Lago Sul, Brasí_lia',
#   'Locality': 'Lago Sul',
#   'Locality Verbose': 'Lago Sul, Brasí_lia',
#   'Longitude': -47.872359,
#   'Latitude': -15.860621,
#   'Cuisines': 'Peruvian, Latin American',
#   'Average Cost for two': 100,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 3.6,
#   'Rating color': 'Yellow',
#   'Rating text': 'Good',
#   'Votes': 5},
#  6601595: {'Restaurant Name': 'Outback Steakhouse',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'ParkShopping - Piso 2, SAI/SO, í\x81rea 6580, Guaríç I, Brasí_lia',
#   'Locality': 'ParkShopping, Guaríç I',
#   'Locality Verbose': 'ParkShopping, Guaríç I, Brasí_lia',
#   'Longitude': -47.95628333,
#   'Latitude': -15.83451389,
#   'Cuisines': 'American, Grill',
#   'Average Cost for two': 150,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.0,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 10},
#  6601158: {'Restaurant Name': 'Manzuíç',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'Pontí£o Lago Sul, SHIS 10, Lote 9, Lago Sul, Brasí_lia',
#   'Locality': 'Pontí£o Lago Sul, Lago Sul',
#   'Locality Verbose': 'Pontí£o Lago Sul, Lago Sul, Brasí_lia',
#   'Longitude': -47.87283333,
#   'Latitude': -15.82566667,
#   'Cuisines': 'Seafood',
#   'Average Cost for two': 240,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 3.2,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 6},
#  6600427: {'Restaurant Name': 'Coco Bambu',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'SCES, Trecho 2, Conjunto 13/36, Setor de Clubes Esportivos Sul, Brasí_lia',
#   'Locality': 'Setor De Clubes Esportivos Sul',
#   'Locality Verbose': 'Setor De Clubes Esportivos Sul, Brasí_lia',
#   'Longitude': -47.8685,
#   'Latitude': -15.819,
#   'Cuisines': 'International',
#   'Average Cost for two': 230,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.9,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 30},
#  6600116: {'Restaurant Name': 'Gero',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'Shopping Iguatemi - piso 1, SHIN CA 4, Lote A, Lago Norte, Brasí_lia',
#   'Locality': 'Shopping Iguatemi, Lago Norte',
#   'Locality Verbose': 'Shopping Iguatemi, Lago Norte, Brasí_lia',
#   'Longitude': -47.885812,
#   'Latitude': -15.720118,
#   'Cuisines': 'Italian',
#   'Average Cost for two': 350,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 3.3,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 8},
#  6601457: {'Restaurant Name': 'Brazilian American Burgers',
#   'Country Code': 30,
#   'City': 'Brasí_lia',
#   'Address': 'CLSN 301, Bloco C, Loja 86, Sudoeste, Brasí_lia',
#   'Locality': 'Sudoeste',
#   'Locality Verbose': 'Sudoeste, Brasí_lia',
#   'Longitude': -47.92102778,
#   'Latitude': -15.79753056,
#   'Cuisines': 'American, Burger',
#   'Average Cost for two': 50,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 3.6,
#   'Rating color': 'Yellow',
#   'Rating text': 'Good',
#   'Votes': 9},
#  7303219: {'Restaurant Name': 'Pesqueiro Eco Gourmet',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Praia da Barra da Tijuca, Avenida Lí_cio Costa, Ilha 25, Barra da Tijuca, Rio de Janeiro',
#   'Locality': 'Barra da Tijuca',
#   'Locality Verbose': 'Barra da Tijuca, Rio de Janeiro',
#   'Longitude': -43.377,
#   'Latitude': -23.0115,
#   'Cuisines': 'Seafood, Bar Food, Brazilian',
#   'Average Cost for two': 140,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.0,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 7},
#  7304307: {'Restaurant Name': 'Confeitaria Colombo',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Rua Goní_alves Dias, 32, Centro, Rio de Janeiro',
#   'Locality': 'Centro',
#   'Locality Verbose': 'Centro, Rio de Janeiro',
#   'Longitude': -43.178826,
#   'Latitude': -22.905293,
#   'Cuisines': 'Desserts, Cafe',
#   'Average Cost for two': 100,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.8,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 29},
#  7301215: {'Restaurant Name': 'Bibi',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Rua Santa Clara, 36, Copabana, Rio de Janeiro',
#   'Locality': 'Copacabana',
#   'Locality Verbose': 'Copacabana, Rio de Janeiro',
#   'Longitude': -43.18669167,
#   'Latitude': -22.97207222,
#   'Cuisines': 'Juices, Healthy Food',
#   'Average Cost for two': 60,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.7,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 24},
#  7300596: {'Restaurant Name': 'Cervantes',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Avenida Prado Junior, 335 B, Copacabana, Rio de Janeiro',
#   'Locality': 'Copacabana',
#   'Locality Verbose': 'Copacabana, Rio de Janeiro',
#   'Longitude': -43.17583333,
#   'Latitude': -22.96216667,
#   'Cuisines': 'Beverages, Bar Food, Fast Food',
#   'Average Cost for two': 90,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.5,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 29},
#  7300612: {'Restaurant Name': 'Amir',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Rua Ronald de Carvalho, 55, Copacabana, Rio de Janeiro',
#   'Locality': 'Copacabana',
#   'Locality Verbose': 'Copacabana, Rio de Janeiro',
#   'Longitude': -43.176,
#   'Latitude': -22.96516667,
#   'Cuisines': 'Lebanese',
#   'Average Cost for two': 170,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.2,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 11},
#  7300704: {'Restaurant Name': 'TT Burger',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Galeria River, Rua Francisco Otaviano, 67, Copacabana, Rio de Janeiro',
#   'Locality': 'Galeria River, Copacabana',
#   'Locality Verbose': 'Galeria River, Copacabana, Rio de Janeiro',
#   'Longitude': -43.191,
#   'Latitude': -22.98683333,
#   'Cuisines': 'Burger',
#   'Average Cost for two': 60,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.8,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 19},
#  7300955: {'Restaurant Name': 'Braseiro da Gíçvea',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Praí_a Santos Dumont, 116, Gíçvea, Rio de Janeiro',
#   'Locality': 'Gíçvea',
#   'Locality Verbose': 'Gíçvea, Rio de Janeiro',
#   'Longitude': -43.227042,
#   'Latitude': -22.973507,
#   'Cuisines': 'Brazilian, Bar Food',
#   'Average Cost for two': 100,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.9,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 40},
#  7300521: {'Restaurant Name': 'Balada Mix',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Rua Aní_bal de Mendoní_a, 37, Ipanema, Rio de Janeiro',
#   'Locality': 'Ipanema',
#   'Locality Verbose': 'Ipanema, Rio de Janeiro',
#   'Longitude': -43.211425,
#   'Latitude': -22.98520833,
#   'Cuisines': 'Brazilian, Healthy Food, Juices, Pizza',
#   'Average Cost for two': 90,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.6,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 21},
#  7300515: {'Restaurant Name': 'Garota de Ipanema',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Rua Vinicius de Moraes, 49, Ipanema, Rio de Janeiro',
#   'Locality': 'Ipanema',
#   'Locality Verbose': 'Ipanema, Rio de Janeiro',
#   'Longitude': -43.203,
#   'Latitude': -22.98533333,
#   'Cuisines': 'Brazilian, Bar Food',
#   'Average Cost for two': 120,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.9,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 49},
#  7300483: {'Restaurant Name': 'Zazíç BistríÇ Tropical',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Rua Joana Angí©lica, 40, Ipanema, Rio de Janeiro',
#   'Locality': 'Ipanema',
#   'Locality Verbose': 'Ipanema, Rio de Janeiro',
#   'Longitude': -43.20520833,
#   'Latitude': -22.98531944,
#   'Cuisines': 'Brazilian',
#   'Average Cost for two': 170,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.6,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 21},
#  7301064: {'Restaurant Name': 'Filí© de Ouro',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Rua Jardim Botí¢nico, 731, Jardim Botí¢nico, Lagoa, Rio de Janeiro',
#   'Locality': 'Lagoa',
#   'Locality Verbose': 'Lagoa, Rio de Janeiro',
#   'Longitude': -43.219563,
#   'Latitude': -22.966647,
#   'Cuisines': 'Brazilian',
#   'Average Cost for two': 90,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.3,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 14},
#  7304312: {'Restaurant Name': 'D.O.C Ristorante',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Le Monde, Bloco 3, Lojas A/B, Avenida das Amí©ricas, 3500, Barra da Tijuca, Rio de Janeiro',
#   'Locality': 'Le Monde, Barra da Tijuca',
#   'Locality Verbose': 'Le Monde, Barra da Tijuca, Rio de Janeiro',
#   'Longitude': -43.34879167,
#   'Latitude': -22.99991111,
#   'Cuisines': 'Italian',
#   'Average Cost for two': 150,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.0,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 5},
#  7300004: {'Restaurant Name': 'Sushi Leblon',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Rua Dias Ferreira, 256, Leblon, Rio de Janeiro',
#   'Locality': 'Leblon',
#   'Locality Verbose': 'Leblon, Rio de Janeiro',
#   'Longitude': -43.227,
#   'Latitude': -22.98416667,
#   'Cuisines': 'Japanese',
#   'Average Cost for two': 250,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.6,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 25},
#  7300868: {'Restaurant Name': 'Talho Capixaba',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Avenida Ataulfo de Paiva, 1022, Lojas A e B, Leblon, Rio de Janeiro',
#   'Locality': 'Leblon',
#   'Locality Verbose': 'Leblon, Rio de Janeiro',
#   'Longitude': -43.22566667,
#   'Latitude': -22.98516667,
#   'Cuisines': 'Bakery, Sandwich, Brazilian',
#   'Average Cost for two': 120,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.4,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 13},
#  7302637: {'Restaurant Name': 'Leme Light',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Rua Gustavo Sampaio, 798, Leme, Rio de Janeiro',
#   'Locality': 'Leme',
#   'Locality Verbose': 'Leme, Rio de Janeiro',
#   'Longitude': -43.17279167,
#   'Latitude': -22.963925,
#   'Cuisines': 'Brazilian',
#   'Average Cost for two': 40,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 4.2,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 7},
#  7302140: {'Restaurant Name': 'Shirley',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Rua Gustavo Sampaio, 610, Leme, Rio de Janeiro',
#   'Locality': 'Leme',
#   'Locality Verbose': 'Leme, Rio de Janeiro',
#   'Longitude': -43.17126389,
#   'Latitude': -22.96337222,
#   'Cuisines': 'Brazilian, Seafood',
#   'Average Cost for two': 250,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.2,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 8},
#  7305048: {'Restaurant Name': 'Quiosque Chopp Brahma',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Madureira Shopping - Loja 289/290, Piso 2, Estrada do Portela, 222, Madureira, Rio de Janeiro, RJ',
#   'Locality': 'Madureira',
#   'Locality Verbose': 'Madureira, Rio de Janeiro',
#   'Longitude': -43.341164,
#   'Latitude': -22.870413,
#   'Cuisines': 'Bar Food, Brazilian',
#   'Average Cost for two': 70,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 0.0,
#   'Rating color': 'White',
#   'Rating text': 'Not rated',
#   'Votes': 1},
#  7302898: {'Restaurant Name': 'Aprazí_vel',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Rua Aprazí_vel, 62, Santa Teresa, Rio de Janeiro',
#   'Locality': 'Santa Teresa',
#   'Locality Verbose': 'Santa Teresa, Rio de Janeiro',
#   'Longitude': -43.18736944,
#   'Latitude': -22.92481389,
#   'Cuisines': 'Brazilian',
#   'Average Cost for two': 300,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.7,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 44},
#  7302859: {'Restaurant Name': 'Aconchego Carioca',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Rua Barí£o de Iguatemi, 379, Tijuca, Rio de Janeiro',
#   'Locality': 'Tijuca',
#   'Locality Verbose': 'Tijuca, Rio de Janeiro',
#   'Longitude': -43.21551111,
#   'Latitude': -22.91370833,
#   'Cuisines': 'Brazilian, Bar Food',
#   'Average Cost for two': 85,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.6,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 24},
#  7301700: {'Restaurant Name': 'Garota de Ipanema',
#   'Country Code': 30,
#   'City': 'Rio de Janeiro',
#   'Address': 'Avenida Joí£o Alves, 56, Urca, Rio de Janeiro',
#   'Locality': 'Urca',
#   'Locality Verbose': 'Urca, Rio de Janeiro',
#   'Longitude': -43.16266667,
#   'Latitude': -22.94783333,
#   'Cuisines': 'Brazilian, Bar Food',
#   'Average Cost for two': 80,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 4.3,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 10},
#  6706313: {'Restaurant Name': 'Cantina Famiglia Mancini',
#   'Country Code': 30,
#   'City': 'Sí£o Paulo',
#   'Address': 'Rua Avanhandava, 81, Bela Vista, Sí£o Paulo 10000',
#   'Locality': 'Bela Vista, Centro',
#   'Locality Verbose': 'Bela Vista, Centro, Sí£o Paulo',
#   'Longitude': -46.64516667,
#   'Latitude': -23.55066667,
#   'Cuisines': 'Italian, Pizza',
#   'Average Cost for two': 250,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.5,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 49},
#  6704326: {'Restaurant Name': 'Templo da Carne - Marcos Bassi',
#   'Country Code': 30,
#   'City': 'Sí£o Paulo',
#   'Address': 'Rua Treze de Maio, 668, Bela Vista, Sí£o Paulo 01327000',
#   'Locality': 'Bela Vista, Centro',
#   'Locality Verbose': 'Bela Vista, Centro, Sí£o Paulo',
#   'Longitude': -46.64633333,
#   'Latitude': -23.559,
#   'Cuisines': 'Steak, BBQ',
#   'Average Cost for two': 250,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.4,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 17},
#  6711179: {'Restaurant Name': 'Gopala Hari',
#   'Country Code': 30,
#   'City': 'Sí£o Paulo',
#   'Address': 'Rua Antonio Carlos, 429, Consolaí_í£o, Sí£o Paulo',
#   'Locality': 'Consolaí_í£o',
#   'Locality Verbose': 'Consolaí_í£o, Sí£o Paulo',
#   'Longitude': -46.65866667,
#   'Latitude': -23.55616667,
#   'Cuisines': 'Indian',
#   'Average Cost for two': 70,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 3.1,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 5},
#  6702797: {'Restaurant Name': 'Jiquitaia',
#   'Country Code': 30,
#   'City': 'Sí£o Paulo',
#   'Address': 'Rua AntíÇnio Carlos, 268, Consolaí_í£o, Sí£o Paulo',
#   'Locality': 'Consolaí_í£o',
#   'Locality Verbose': 'Consolaí_í£o, Sí£o Paulo',
#   'Longitude': -46.657523,
#   'Latitude': -23.55671,
#   'Cuisines': 'Brazilian',
#   'Average Cost for two': 100,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.1,
#   'Rating color': 'Green',
#   'Rating text': 'Very Good',
#   'Votes': 15},
#  6700475: {'Restaurant Name': 'Skye - Hotel Unique',
#   'Country Code': 30,
#   'City': 'Sí£o Paulo',
#   'Address': 'Hotel Unique, Avenida Brigadeiro Luí_s AntíÇnio, 4700, Jardim Paulista, Sí£o Paulo',
#   'Locality': 'Hotel Unique, Jardim Paulista',
#   'Locality Verbose': 'Hotel Unique, Jardim Paulista, Sí£o Paulo',
#   'Longitude': -46.666851,
#   'Latitude': -23.581688,
#   'Cuisines': 'Beverages, International',
#   'Average Cost for two': 300,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.8,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 59},
#  6713413: {'Restaurant Name': 'Les 3 Brasseurs',
#   'Country Code': 30,
#   'City': 'Sí£o Paulo',
#   'Address': 'Rua Jesuí_no Arruda, 470, Itaim Bibi, Sí£o Paulo',
#   'Locality': 'Itaim Bibi',
#   'Locality Verbose': 'Itaim Bibi, Sí£o Paulo',
#   'Longitude': -46.67511,
#   'Latitude': -23.582135,
#   'Cuisines': 'French, Brazilian, Beverages',
#   'Average Cost for two': 120,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 4.6,
#   'Rating color': 'Dark Green',
#   'Rating text': 'Excellent',
#   'Votes': 30},
#  6714340: {'Restaurant Name': 'Red Steak & Burger',
#   'Country Code': 30,
#   'City': 'Sí£o Paulo',
#   'Address': 'Rua Tabapuí£, 1417, Itaim Bibi, Sí£o Paulo',
#   'Locality': 'Itaim Bibi',
#   'Locality Verbose': 'Itaim Bibi, Sí£o Paulo',
#   'Longitude': -46.683888,
#   'Latitude': -23.585324,
#   'Cuisines': 'Brazilian, Grill',
#   'Average Cost for two': 75,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 3,
#   'Aggregate rating': 3.9,
#   'Rating color': 'Yellow',
#   'Rating text': 'Good',
#   'Votes': 5},
#  6710645: {'Restaurant Name': 'Cantinho da Gula',
#   'Country Code': 30,
#   'City': 'Sí£o Paulo',
#   'Address': 'Rua Pedroso Alvarenga, 522, Itaim Bibi, Sí£o Paulo, SP',
#   'Locality': 'Itaim Bibi',
#   'Locality Verbose': 'Itaim Bibi, Sí£o Paulo',
#   'Longitude': -46.67566667,
#   'Latitude': -23.581,
#   'Cuisines': 'Brazilian',
#   'Average Cost for two': 55,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 0.0,
#   'Rating color': 'White',
#   'Rating text': 'Not rated',
#   'Votes': 0},
#  6700402: {'Restaurant Name': 'Paris 6 Classique',
#   'Country Code': 30,
#   'City': 'Sí£o Paulo',
#   'Address': 'Rua Haddock Lobo, 1240, Cerqueira Cí©sar, Jardim Paulista, Sí£o Paulo',
#   'Locality': 'Jardim Paulista',
#   'Locality Verbose': 'Jardim Paulista, Sí£o Paulo',
#   'Longitude': -46.666041,
#   'Latitude': -23.561568,
#   'Cuisines': 'French',
#   'Average Cost for two': 200,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 3.4,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 73},
#  6700846: {'Restaurant Name': 'Kawa Sushi',
#   'Country Code': 30,
#   'City': 'Sí£o Paulo',
#   'Address': 'Alameda Lorena, 300, Jardim Paulista, Sí£o Paulo',
#   'Locality': 'Jardim Paulista',
#   'Locality Verbose': 'Jardim Paulista, Sí£o Paulo',
#   'Longitude': -46.657418,
#   'Latitude': -23.571638,
#   'Cuisines': 'Sushi, Japanese',
#   'Average Cost for two': 120,
#   'Currency': 'Brazilian Real(R$)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 4,
#   'Aggregate rating': 3.5,
#   'Rating color': 'Yellow',
#   'Rating text': 'Good',
#   'Votes': 9},
#  6702159: {'Restaurant Name': 'A Figueira Rubaiyat',
#   'Country Code': 30,
#   'City': 'Sí£o Paulo',
#   'Address': 'Rua Haddock Lobo, 1738, Cerqueira Cí©sar, Jardim Paulista, Sí£o Paulo 10000',
# ...
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 0.0,
#   'Rating color': 'White',
#   'Rating text': 'Not rated',
#   'Votes': 2},
#  18466939: {'Restaurant Name': 'Maa Kali Foods',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': 'SCO 35, HUDA Market, Sector 16, Faridabad',
#   'Locality': 'Sector 16',
#   'Locality Verbose': 'Sector 16, Faridabad',
#   'Longitude': 77.3196991,
#   'Latitude': 28.4104999,
#   'Cuisines': 'Chinese',
#   'Average Cost for two': 250,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 0.0,
#   'Rating color': 'White',
#   'Rating text': 'Not rated',
#   'Votes': 0},
#  18380180: {'Restaurant Name': 'The Street Kitchen',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': 'Shop 139, Main HUDA Market, Sector 16, Faridabad',
#   'Locality': 'Sector 16',
#   'Locality Verbose': 'Sector 16, Faridabad',
#   'Longitude': 77.3185772,
#   'Latitude': 28.4107084,
#   'Cuisines': 'North Indian, Chinese',
#   'Average Cost for two': 400,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 0.0,
#   'Rating color': 'White',
#   'Rating text': 'Not rated',
#   'Votes': 0},
#  18466407: {'Restaurant Name': 'United Kitchen',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': '2nd Floor, SCO 95, HUDA Market, Sector 16, Faridabad',
#   'Locality': 'Sector 16',
#   'Locality Verbose': 'Sector 16, Faridabad',
#   'Longitude': 77.3189708,
#   'Latitude': 28.4120254,
#   'Cuisines': 'Fast Food',
#   'Average Cost for two': 500,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 0.0,
#   'Rating color': 'White',
#   'Rating text': 'Not rated',
#   'Votes': 0},
#  304001: {'Restaurant Name': 'Eat N Treat',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': '145, Main Market, Sector 17, Faridabad',
#   'Locality': 'Sector 17',
#   'Locality Verbose': 'Sector 17, Faridabad',
#   'Longitude': 77.3266023,
#   'Latitude': 28.4101024,
#   'Cuisines': 'Chinese, North Indian',
#   'Average Cost for two': 400,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 2.8,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 20},
#  8319: {'Restaurant Name': 'Hotel Ekant',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': '12 - 14, Sector 17, Faridabad',
#   'Locality': 'Sector 17',
#   'Locality Verbose': 'Sector 17, Faridabad',
#   'Longitude': 77.329167,
#   'Latitude': 28.4101795,
#   'Cuisines': 'North Indian, Mughlai, Chinese',
#   'Average Cost for two': 700,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 2.7,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 39},
#  303871: {'Restaurant Name': 'Momo-Cha',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': '31, Near HDFC Bank ATM, Sector 17 Market, Sector 17, Faridabad',
#   'Locality': 'Sector 17',
#   'Locality Verbose': 'Sector 17, Faridabad',
#   'Longitude': 77.3288978,
#   'Latitude': 28.4106029,
#   'Cuisines': 'North Indian, Chinese',
#   'Average Cost for two': 600,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'Yes',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 2.7,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 56},
#  8321: {'Restaurant Name': 'Paradise Inn',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': '124, Near OBC Bank, Sector 17 Market, Faridabad, Sector 17, Faridabad',
#   'Locality': 'Sector 17',
#   'Locality Verbose': 'Sector 17, Faridabad',
#   'Longitude': 77.3275764,
#   'Latitude': 28.4103725,
#   'Cuisines': 'North Indian, Mughlai, Chinese',
#   'Average Cost for two': 500,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 2.7,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 43},
#  311047: {'Restaurant Name': 'Red Chilli',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': 'Shop 140, Back Side, Main Market, Sector 17, Faridabad',
#   'Locality': 'Sector 17',
#   'Locality Verbose': 'Sector 17, Faridabad',
#   'Longitude': 77.326744,
#   'Latitude': 28.4099515,
#   'Cuisines': 'Chinese',
#   'Average Cost for two': 300,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 2.8,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 9},
#  8320: {'Restaurant Name': 'Shiv Restaurant',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': '122 & 123, HUDA Market, Sector 17, Faridabad',
#   'Locality': 'Sector 17',
#   'Locality Verbose': 'Sector 17, Faridabad',
#   'Longitude': 77.3278324,
#   'Latitude': 28.4101647,
#   'Cuisines': 'North Indian',
#   'Average Cost for two': 400,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 2.7,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 20},
#  8308: {'Restaurant Name': 'Sohan Sweets & Namkeen',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': '115 & 116, Sector 17, Faridabad',
#   'Locality': 'Sector 17',
#   'Locality Verbose': 'Sector 17, Faridabad',
#   'Longitude': 77.3279106,
#   'Latitude': 28.4103306,
#   'Cuisines': 'Mithai',
#   'Average Cost for two': 100,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 3.2,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 41},
#  18303717: {'Restaurant Name': 'The Binge Box Cafe',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': '1st  Floor, 110, HUDA Market, Sector 17, Faridabad',
#   'Locality': 'Sector 17',
#   'Locality Verbose': 'Sector 17, Faridabad',
#   'Longitude': 77.3279106,
#   'Latitude': 28.4105998,
#   'Cuisines': 'Cafe',
#   'Average Cost for two': 500,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 3.4,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 18},
#  304004: {'Restaurant Name': 'Tmos Moving Feast',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': '156, Main Market, Sector 17, Faridabad',
#   'Locality': 'Sector 17',
#   'Locality Verbose': 'Sector 17, Faridabad',
#   'Longitude': 77.32609671,
#   'Latitude': 28.4101156,
#   'Cuisines': 'Chinese, North Indian',
#   'Average Cost for two': 700,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'Yes',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 3.3,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 76},
#  18472625: {'Restaurant Name': 'Tmos Cafe Corner',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': 'Shop 164, Huda Market, Sector 17, Faridabad',
#   'Locality': 'Sector 17',
#   'Locality Verbose': 'Sector 17, Faridabad',
#   'Longitude': 77.326227,
#   'Latitude': 28.409801,
#   'Cuisines': 'Cafe',
#   'Average Cost for two': 700,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'Yes',
#   'Has Online delivery': 'Yes',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 0.0,
#   'Rating color': 'White',
#   'Rating text': 'Not rated',
#   'Votes': 1},
#  18420432: {'Restaurant Name': 'Parkash Dhaba',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': 'Shop 32, HUDA Market, Sector 19, Faridabad',
#   'Locality': 'Sector 19',
#   'Locality Verbose': 'Sector 19, Faridabad',
#   'Longitude': 77.3138205,
#   'Latitude': 28.417529,
#   'Cuisines': 'North Indian, Chinese',
#   'Average Cost for two': 200,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 3.0,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 6},
#  9824: {'Restaurant Name': 'Sanjha Chulha',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': 'Booth 16, Part 2 Market, Sector 19, Faridabad',
#   'Locality': 'Sector 19',
#   'Locality Verbose': 'Sector 19, Faridabad',
#   'Longitude': 77.3144487,
#   'Latitude': 28.4175882,
#   'Cuisines': 'North Indian, Mughlai',
#   'Average Cost for two': 700,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'Yes',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 3.3,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 219},
#  8029: {'Restaurant Name': 'Hareram Bikanerzaika',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': '77 & 78, HUDA Market, Opposite Community Centre, Sector 21 C, Near Sector 21, Faridabad',
#   'Locality': 'Sector 21',
#   'Locality Verbose': 'Sector 21, Faridabad',
#   'Longitude': 77.2969594,
#   'Latitude': 28.4304159,
#   'Cuisines': 'Mithai, Street Food',
#   'Average Cost for two': 200,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 2.8,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 11},
#  312788: {'Restaurant Name': 'Kulcha Paaji',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': 'Opposite 21-C Market, Sector 21, Faridabad',
#   'Locality': 'Sector 21',
#   'Locality Verbose': 'Sector 21, Faridabad',
#   'Longitude': 77.2967664,
#   'Latitude': 28.4317132,
#   'Cuisines': 'Street Food',
#   'Average Cost for two': 100,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 3.1,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 12},
#  309672: {'Restaurant Name': 'Shree Bikaner Misthan Bhandar',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': 'DSS 44, Sector 21, Faridabad',
#   'Locality': 'Sector 21',
#   'Locality Verbose': 'Sector 21, Faridabad',
#   'Longitude': 77.2964432,
#   'Latitude': 28.4301217,
#   'Cuisines': 'Street Food, South Indian, Mithai',
#   'Average Cost for two': 350,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 2.8,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 13},
#  18359861: {'Restaurant Name': 'The Hub - Gourmet, Bakers & More',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': 'Asian Institute of Medical Sciences, Badkal Flyover, Sector 21 A, Sector 21, Faridabad',
#   'Locality': 'Sector 21',
#   'Locality Verbose': 'Sector 21, Faridabad',
#   'Longitude': 0.0,
#   'Latitude': 0.0,
#   'Cuisines': 'Bakery, Fast Food',
#   'Average Cost for two': 200,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 3.0,
#   'Rating color': 'Orange',
#   'Rating text': 'Average',
#   'Votes': 7},
#  18439547: {'Restaurant Name': 'Anand Dhaba',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': 'DSS-38, Sector 21C Market, Sector 21, Faridabad',
#   'Locality': 'Sector 21',
#   'Locality Verbose': 'Sector 21, Faridabad',
#   'Longitude': 77.2963379,
#   'Latitude': 28.4298355,
#   'Cuisines': 'North Indian',
#   'Average Cost for two': 200,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 0.0,
#   'Rating color': 'White',
#   'Rating text': 'Not rated',
#   'Votes': 1},
#  18241538: {'Restaurant Name': 'Bikaneri Sweets & Restaurant',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': 'Ankhir Road, Near Union Bank, Opposite Sector 21-D, Sector 21, Faridabad',
#   'Locality': 'Sector 21',
#   'Locality Verbose': 'Sector 21, Faridabad',
#   'Longitude': 0.0,
#   'Latitude': 0.0,
#   'Cuisines': 'Mithai, North Indian',
#   'Average Cost for two': 250,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 0.0,
#   'Rating color': 'White',
#   'Rating text': 'Not rated',
#   'Votes': 0},
#  18452730: {'Restaurant Name': 'Delicieux Ice Cream Rolls',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': 'Shop 73, Main Market, Sector 21 C, Sector 21, Faridabad',
#   'Locality': 'Sector 21',
#   'Locality Verbose': 'Sector 21, Faridabad',
#   'Longitude': 77.2969354,
#   'Latitude': 28.4300562,
#   'Cuisines': 'Ice Cream, Desserts, Beverages',
#   'Average Cost for two': 400,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 0.0,
#   'Rating color': 'White',
#   'Rating text': 'Not rated',
#   'Votes': 1},
#  18317486: {'Restaurant Name': 'Flying Tandoor',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': 'Shop 57, Sector 21D Market, Sector 21, Faridabad',
#   'Locality': 'Sector 21',
#   'Locality Verbose': 'Sector 21, Faridabad',
#   'Longitude': 77.291919,
#   'Latitude': 28.4221037,
#   'Cuisines': 'North Indian, Fast Food',
#   'Average Cost for two': 300,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 0.0,
#   'Rating color': 'White',
#   'Rating text': 'Not rated',
#   'Votes': 3},
#  18432933: {'Restaurant Name': 'Food Station',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': 'G-5, Post Office Gali, Indra Enclave, Sector 21-D, Sector 21, Faridabad',
#   'Locality': 'Sector 21',
#   'Locality Verbose': 'Sector 21, Faridabad',
#   'Longitude': 0.0,
#   'Latitude': 0.0,
#   'Cuisines': 'North Indian, Mughlai, Chinese',
#   'Average Cost for two': 400,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 1,
#   'Aggregate rating': 0.0,
#   'Rating color': 'White',
#   'Rating text': 'Not rated',
#   'Votes': 0},
#  18452267: {'Restaurant Name': 'Grub Hub',
#   'Country Code': 1,
#   'City': 'Faridabad',
#   'Address': 'Shop 11, HUDA Main Market, Behind Park Plaza Hotel, Sector 21-C, Sector 21, Faridabad',
#   'Locality': 'Sector 21',
#   'Locality Verbose': 'Sector 21, Faridabad',
#   'Longitude': 77.2964494,
#   'Latitude': 28.4296999,
#   'Cuisines': 'Asian',
#   'Average Cost for two': 500,
#   'Currency': 'Indian Rupees(Rs.)',
#   'Has Table booking': 'No',
#   'Has Online delivery': 'No',
#   'Is delivering now': 'No',
#   'Switch to order menu': 'No',
#   'Price range': 2,
#   'Aggregate rating': 0.0,
#   'Rating color': 'White',
#   'Rating text': 'Not rated',
#   'Votes': 1},
#  ...}

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17204\3911115265.py in ?()
#       1 #We can see that the Restaurant ID is unique. So, we can use it as the index of the DataFrame.
# ----> 2 zomoto_data.set_index('Restaurant ID', inplace=True)
#       3 # fucntion for get restaurant by id
#       4 def get_restaurant_by_id(restaurant_id):
#       5     # first check if the restaurant_id exists in the DataFrame
#
# c:\Users\Lokes\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Restaurant ID'] are in the columns"
